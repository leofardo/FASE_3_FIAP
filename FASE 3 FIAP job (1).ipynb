# %%
# Importa bibliotecas do Glue e Spark
import sys
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from pyspark.sql import SparkSession

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 1.0.8
# Trying to create a Glue session for the kernel.
# Session Type: glueetl
# Session ID: b744bdcf-13d8-4294-8dfc-6a7872a87a7c
# Applying the following default arguments:
# --glue_kernel_version 1.0.8
# --enable-glue-datacatalog true
# Waiting for session b744bdcf-13d8-4294-8dfc-6a7872a87a7c to get into ready status...
# Session b744bdcf-13d8-4294-8dfc-6a7872a87a7c has been created.

# %% [markdown]
# # LEVANTANDO AS BASES (BRONZE)

# %% [markdown]
# ## DICIONÁRIO BASE

# %%
#Peguei o dicionário original, retirei celulas mescladas e fiz um Fill nos valores que ficaram nulos (código em outro notebook)

dict_path_csv = "s3://898876087650/data_input/tech_challenge_fase3/dicionario/Dicionario_PNAD_COVID_092020_tratado.csv"

pdf_dict = spark.read \
    .option("header", True) \
    .option("delimiter", ";") \
    .option("charset", "ISO-8859-1") \
    .csv(dict_path_csv)

pdf_dict.show()
# Out:
# +------------------+--------------------+----+-------------------+
# |Código da variável|           Descrição|Tipo|        Descrição.1|
# +------------------+--------------------+----+-------------------+
# |                UF|Unidade da Federação|  11|           Rondônia|
# |                UF|Unidade da Federação|  12|               Acre|
# |                UF|Unidade da Federação|  13|           Amazonas|
# |                UF|Unidade da Federação|  14|            Roraima|
# |                UF|Unidade da Federação|  15|               Pará|
# |                UF|Unidade da Federação|  16|              Amapá|
# |                UF|Unidade da Federação|  17|          Tocantins|
# |                UF|Unidade da Federação|  21|           Maranhão|
# |                UF|Unidade da Federação|  22|              Piauí|
# |                UF|Unidade da Federação|  23|              Ceará|
# |                UF|Unidade da Federação|  24|Rio Grande do Norte|
# |                UF|Unidade da Federação|  25|            Paraíba|
# |                UF|Unidade da Federação|  26|         Pernambuco|
# |                UF|Unidade da Federação|  27|            Alagoas|
# |                UF|Unidade da Federação|  28|            Sergipe|
# |                UF|Unidade da Federação|  29|              Bahia|
# |                UF|Unidade da Federação|  31|       Minas Gerais|
# |                UF|Unidade da Federação|  32|     Espírito Santo|
# |                UF|Unidade da Federação|  33|     Rio de Janeiro|
# |                UF|Unidade da Federação|  35|          São Paulo|
# +------------------+--------------------+----+-------------------+
# only showing top 20 rows

# %%
# Ajusta os nomes das colunas do dicionário
df_dict = pdf_dict.withColumnRenamed("Código da variável", "codigo") \
                  .withColumnRenamed("Descrição", "descricao_coluna") \
                  .withColumnRenamed("Tipo", "tipo_valor") \
                  .withColumnRenamed("Descrição.1", "descricao_valor")

col_rename_dict = {row['codigo']: row['descricao_coluna'] for row in df_dict.collect()}

df_dict.show(5)
# Out:
# +------+--------------------+----------+---------------+
# |codigo|    descricao_coluna|tipo_valor|descricao_valor|
# +------+--------------------+----------+---------------+
# |    UF|Unidade da Federação|        11|       Rondônia|
# |    UF|Unidade da Federação|        12|           Acre|
# |    UF|Unidade da Federação|        13|       Amazonas|
# |    UF|Unidade da Federação|        14|        Roraima|
# |    UF|Unidade da Federação|        15|           Pará|
# +------+--------------------+----------+---------------+
# only showing top 5 rows

# %%
#Criar um dicionário de mapeamento código -> descrição
dict_mapping = pdf_dict.select("Código da variável", "Descrição").rdd.collectAsMap()

dict_mapping
# Out:
# {'UF': 'Unidade da Federação', 'CAPITAL': 'Capital', 'RM_RIDE': 'Região Metropolitana e Região Administrativa Integrada de Desenvolvimento', 'Luís (MA)"': None, 'de Desenvolvimento da Grande Teresina (PI)"': None, 'V1008': 'Número de seleção do domicílio', 'V1012': 'Semana no mês', 'V1013': 'Mês da pesquisa', 'V1016': 'Número da entrevista no domicílio', 'Estrato': 'Estrato', 'UPA': 'UPA', 'V1022': 'Situação do domicílio', 'V1023': 'Tipo de área', 'V1030': 'Projeção da população', 'V1031': 'Peso do domicílio e das pessoas', 'V1032': 'Peso do domicílio e das pessoas', 'posest': 'Domínios de projeção', 'A001': 'Número de ordem', 'A001A': 'Condição no domicílio', 'A001B1': 'Dia de nascimento', 'A001B2': 'Mês de nascimento', 'A001B3': 'Ano de nascimento', 'A002': 'Idade do morador ', 'A003': 'Sexo', 'A004': 'Cor ou raça', 'A005': 'Escolaridade', 'A006': 'Frequenta escola', 'A007': 'Na semana passada, _____ foram disponibilizadas atividades escolares para realizar em casa?', 'A008': 'Na semana passada, em quantos dias _____ dedicou-se às atividades escolares? ', 'A009': 'Na semana passada, quanto tempo por dia ____ gastou fazendo as atividades escolares?  escolares? ', 'B0011': 'Na semana passada teve febre?', 'B0012': 'Na semana passada teve tosse?', 'B0013': 'Na semana passada teve dor de garganta?', 'B0014': 'Na semana passada teve dificuldade para respirar?', 'B0015': 'Na semana passada teve dor de cabeça?', 'B0016': 'Na semana passada teve dor no peito?', 'B0017': 'Na semana passada teve náusea?', 'B0018': 'Na semana passada teve nariz entupido ou escorrendo?', 'B0019': 'Na semana passada teve fadiga?', 'B00110': 'Na semana passada teve dor nos olhos?', 'B00111': 'Na semana passada teve perda de cheiro ou sabor?', 'B00112': 'Na semana passada teve dor muscular?', 'B00113': 'Na semana passada teve diarreia?', 'B002': 'Por causa disso, foi a algum estabelecimento de saúde?', 'B0031': 'Providência tomada para recuperar dos sintomas foi ficar em casa', 'B0032': 'Providência tomada para recuperar dos sintomas foi ligar para algum profissional de saúde', 'B0033': 'Providência tomada  para recuperar dos sintomas foi comprar e/ou tomar  remédio por conta própria', 'B0034': 'Providência tomada para recuperar dos sintomas foi comprar e/ou tomar remédio por orientação médica', 'B0035': 'Providência tomada para recuperar dos sintomas foi receber visita de algum profissional de saúde do SUS (equipe de saúde da família, agente comunitário, etc.)', 'B0036': 'Providência tomada para recuperar dos sintomas foi receber visita de profissional de saúde particular ', 'B0037': 'Providência tomada para recuperar dos sintomas foi outra', 'B0041': 'Local que buscou atendimento foi posto de saúde/Unidade básica de saúde /Equipe de Saúde da Família (médico, enfermeiro, técnico de enfermagem ou agente comunitário de saúde)', 'B0042': 'Local que buscou atendimento foi pronto socorro do SUS/UPA', 'B0043': 'Local que buscou atendimento foi hospital do SUS', 'B0044': 'Local que buscou atendimento foi ambulatório ou consultório privado ou ligado às forças armadas', 'B0045': 'Local que buscou atendimento foi pronto socorro privado ou ligado às forças armadas', 'B0046': 'Local que buscou atendimento foi hospital privado ou ligado às forças armadas', 'B005': 'Ao procurar o hospital, teve que ficar internado por um dia ou mais', 'B006': 'Durante a internação, foi sedado, entubado e colocado em respiração artificial com ventilador', 'B007': 'Tem algum plano de saúde médico, seja particular, de empresa ou de órgão público', 'B008': 'O(A) Sr(a) fez algum teste para saber se estava infectado(a) pelo coronavírus? ', 'B009A': 'Fez o exame coletado com cotonete na boca e/ou nariz (SWAB)? ', 'B009B': 'Qual o resultado?', 'B009C': 'Fez o exame de coleta de sangue através de furo no dedo?', 'B009D': 'Qual o resultado?', 'B009E': 'Fez o exame de coleta de sangue através da veia da braço?', 'B009F': 'Qual o resultado?', 'B0101': 'Algum médico já lhe deu o diagnóstico de diab ...

# %% [markdown]
# ## BASES PNAD

# %%
from pyspark.sql import functions as F

df_set = spark.read.option("header", True).option("inferSchema", True).csv("s3://898876087650/data_input/tech_challenge_fase3/092020/PNAD_COVID_092020.csv")
df_out = spark.read.option("header", True).option("inferSchema", True).csv("s3://898876087650/data_input/tech_challenge_fase3/102020/PNAD_COVID_102020.csv")
df_nov = spark.read.option("header", True).option("inferSchema", True).csv("s3://898876087650/data_input/tech_challenge_fase3/112020/PNAD_COVID_112020.csv")

# df de novembro tem algumas colunas a mais, então estou tirando essas colunas a mais pra ficar os três periodos iguais
df_nov = df_nov.select(df_set.columns)

# adiciona coluna do período
df_set = df_set.withColumn("periodo", F.lit("09/2020"))
df_out = df_out.withColumn("periodo", F.lit("10/2020"))
df_nov = df_nov.withColumn("periodo", F.lit("11/2020"))

df_nov.columns
# Out:
# ['Ano', 'UF', 'CAPITAL', 'RM_RIDE', 'V1008', 'V1012', 'V1013', 'V1016', 'Estrato', 'UPA', 'V1022', 'V1023', 'V1030', 'V1031', 'V1032', 'posest', 'A001', 'A001A', 'A001B1', 'A001B2', 'A001B3', 'A002', 'A003', 'A004', 'A005', 'A006', 'A007', 'A008', 'A009', 'B0011', 'B0012', 'B0013', 'B0014', 'B0015', 'B0016', 'B0017', 'B0018', 'B0019', 'B00110', 'B00111', 'B00112', 'B00113', 'B002', 'B0031', 'B0032', 'B0033', 'B0034', 'B0035', 'B0036', 'B0037', 'B0041', 'B0042', 'B0043', 'B0044', 'B0045', 'B0046', 'B005', 'B006', 'B007', 'B008', 'B009A', 'B009B', 'B009C', 'B009D', 'B009E', 'B009F', 'B0101', 'B0102', 'B0103', 'B0104', 'B0105', 'B0106', 'B011', 'C001', 'C002', 'C003', 'C004', 'C005', 'C0051', 'C0052', 'C0053', 'C006', 'C007', 'C007A', 'C007B', 'C007C', 'C007D', 'C007E', 'C007E1', 'C007E2', 'C007F', 'C008', 'C009', 'C009A', 'C010', 'C0101', 'C01011', 'C01012', 'C0102', 'C01021', 'C01022', 'C0103', 'C0104', 'C011A', 'C011A1', 'C011A11', 'C011A12', 'C011A2', 'C011A21', 'C011A22', 'C012', 'C013', 'C014', 'C015', 'C016', 'C017A', 'D0011', 'D0013', 'D0021', 'D0023', 'D0031', 'D0033', 'D0041', 'D0043', 'D0051', 'D0053', 'D0061', 'D0063', 'D0071', 'D0073', 'E001', 'E0021', 'E0022', 'E0023', 'E0024', 'F001', 'F0021', 'F0022', 'F002A1', 'F002A2', 'F002A3', 'F002A4', 'F002A5', 'F0061', 'F006', 'periodo']

# %%
df_total = df_set.unionByName(df_out).unionByName(df_nov)

df_total.count()
# Out:
# 1149197

# %% [markdown]
# # RENOMEANDO AS COLUNAS COM AS COLUNAS DO DICIONÁRIO (SILVER)

# %%
# Função para renomear as colunas com formato "CÓDIGO - DESCRIÇÃO"
def rename_columns_with_dict(df, mapping_dict):
    # Para cada coluna no DataFrame
    for old_col in df.columns:
        # Se a coluna existe no dicionário, renomeia com formato "CÓDIGO - DESCRIÇÃO"
        if old_col in mapping_dict:
            new_col_name = f"{old_col} - {mapping_dict[old_col]}"
            df = df.withColumnRenamed(old_col, new_col_name)
    return df

df_total_renomeado = rename_columns_with_dict(df_total, dict_mapping)

# Verificar o resultado
print("Colunas originais vs renomeadas:")
for i, col in enumerate(df_total.columns[:10]):  # Mostra apenas as primeiras 10
    old_name = col
    if i < len(df_total_renomeado.columns):
        new_name = df_total_renomeado.columns[i]
        print(f"{old_name} -> {new_name}")
# Out:
# Colunas originais vs renomeadas:
# Ano -> Ano
# UF -> UF - Unidade da Federação
# CAPITAL -> CAPITAL - Capital
# RM_RIDE -> RM_RIDE - Região Metropolitana e Região Administrativa Integrada de Desenvolvimento
# V1008 -> V1008 - Número de seleção do domicílio
# V1012 -> V1012 - Semana no mês
# V1013 -> V1013 - Mês da pesquisa
# V1016 -> V1016 - Número da entrevista no domicílio
# Estrato -> Estrato - Estrato
# UPA -> UPA - UPA

# %%
df_total_renomeado.printSchema()
# Out:
# root
#  |-- Ano: integer (nullable = true)
#  |-- UF - Unidade da Federação: integer (nullable = true)
#  |-- CAPITAL - Capital: integer (nullable = true)
#  |-- RM_RIDE - Região Metropolitana e Região Administrativa Integrada de Desenvolvimento: integer (nullable = true)
#  |-- V1008 - Número de seleção do domicílio: integer (nullable = true)
#  |-- V1012 - Semana no mês: integer (nullable = true)
#  |-- V1013 - Mês da pesquisa: integer (nullable = true)
#  |-- V1016 - Número da entrevista no domicílio: integer (nullable = true)
#  |-- Estrato - Estrato: integer (nullable = true)
#  |-- UPA - UPA: integer (nullable = true)
#  |-- V1022 - Situação do domicílio: integer (nullable = true)
#  |-- V1023 - Tipo de área: integer (nullable = true)
#  |-- V1030 - Projeção da população: integer (nullable = true)
#  |-- V1031 - Peso do domicílio e das pessoas: double (nullable = true)
#  |-- V1032 - Peso do domicílio e das pessoas: double (nullable = true)
#  |-- posest - Domínios de projeção: integer (nullable = true)
#  |-- A001 - Número de ordem: integer (nullable = true)
#  |-- A001A - Condição no domicílio: integer (nullable = true)
#  |-- A001B1 - Dia de nascimento: integer (nullable = true)
#  |-- A001B2 - Mês de nascimento: integer (nullable = true)
#  |-- A001B3 - Ano de nascimento: integer (nullable = true)
#  |-- A002 - Idade do morador : integer (nullable = true)
#  |-- A003 - Sexo: integer (nullable = true)
#  |-- A004 - Cor ou raça: integer (nullable = true)
#  |-- A005 - Escolaridade: integer (nullable = true)
#  |-- A006 - Frequenta escola: integer (nullable = true)
#  |-- A007 - Na semana passada, _____ foram disponibilizadas atividades escolares para realizar em casa?: integer (nullable = true)
#  |-- A008 - Na semana passada, em quantos dias _____ dedicou-se às atividades escolares? : integer (nullable = true)
#  |-- A009 - Na semana passada, quanto tempo por dia ____ gastou fazendo as atividades escolares?  escolares? : integer (nullable = true)
#  |-- B0011 - Na semana passada teve febre?: integer (nullable = true)
#  |-- B0012 - Na semana passada teve tosse?: integer (nullable = true)
#  |-- B0013 - Na semana passada teve dor de garganta?: integer (nullable = true)
#  |-- B0014 - Na semana passada teve dificuldade para respirar?: integer (nullable = true)
#  |-- B0015 - Na semana passada teve dor de cabeça?: integer (nullable = true)
#  |-- B0016 - Na semana passada teve dor no peito?: integer (nullable = true)
#  |-- B0017 - Na semana passada teve náusea?: integer (nullable = true)
#  |-- B0018 - Na semana passada teve nariz entupido ou escorrendo?: integer (nullable = true)
#  |-- B0019 - Na semana passada teve fadiga?: integer (nullable = true)
#  |-- B00110 - Na semana passada teve dor nos olhos?: integer (nullable = true)
#  |-- B00111 - Na semana passada teve perda de cheiro ou sabor?: integer (nullable = true)
#  |-- B00112 - Na semana passada teve dor muscular?: integer (nullable = true)
#  |-- B00113 - Na semana passada teve diarreia?: integer (nullable = true)
#  |-- B002 - Por causa disso, foi a algum estabelecimento de saúde?: integer (nullable = true)
#  |-- B0031 - Providência tomada para recuperar dos sintomas foi ficar em casa: integer (nullable = true)
#  |-- B0032 - Providência tomada para recuperar dos sintomas foi ligar para algum profissional de saúde: integer (nullable = true)
#  |-- B0033 - Providência tomada  para recuperar dos sintomas foi comprar e/ou tomar  remédio por conta própria: integer (nullable = true)
#  |-- B0034 - Providência tomada para recuperar dos sintomas foi comprar e/ou tomar remédio por orientação médica: integer (nullable = true)
#  |-- B0035 - Providência tomada para recuperar dos sintomas foi receber visita de algum profissional de saúde do SUS (equipe de saúde da família, agente comunitário, etc.): integer (nullable = true)
#  |-- B0036 - Providência tomada para recuperar dos sintomas foi receber visita de profissional de saúde particular : integer (nullable = true)
#  |-- B0037 - Providência tomada para recuperar dos sintomas foi outra: integer (nullable = true)
#  |-- B0041 - Local que buscou atendimento foi posto de saúde/Unidade básica de saúde /Equipe de Saúde da Família (médico, enfermeiro, técnico de enfermagem ou agente comunitário de saúde): integer (nullable = true)
#  |-- B0042 - Local que buscou atendimento foi pronto socorro do SUS/UPA: integer (nullable = true)
#  |-- B0043 - Local que buscou atendimento foi hospital do SUS: integer (nullable = true)
#  |-- B0044 - Local que buscou atendimento foi ambulatório ou consultório privado ou ligado às forças armadas: integer (nullable = true)
#  |-- B0045 - Local que buscou atendimento foi pronto socorro privado ou ligado às forças armadas: integer (nullable = true)
#  |-- B0046 - Local que buscou atendimento foi hospital privado ou ligado às forças armadas: integer (nullable = true)
#  |-- B005 - Ao procurar o hospital, teve que ficar internado por um dia ou mais: integer (nullable = true)
#  |-- B006 - Durante a internação, foi sedado, entubado e colocado em respiração artificial com ventilador: integer (nullable = true)
#  |-- B007 - Tem algum plano de saúde médico, seja particular, de empresa ou de órgão público: integer (nullable = true)
#  |-- B008 - O(A) Sr(a) fez algum teste para saber se estava infectado(a) pelo coronavírus? : integer (nullable = true)
#  |-- B009A - Fez o exame coletado com cotonete na boca e/ou nariz (SWAB)? : integer (nullable = true)
#  |-- B009B - Qual o resultado?: integer (nullable = true)
#  |-- B009C - Fez o exame de coleta de sangue através de furo no dedo?: integer (nullable = true)
#  |-- B009D - Qual o resultado?: integer (nullable = true)
#  |-- B009E - Fez o exame de coleta de sangue através da veia da braço?: integer (nullable = true)
#  |-- B009F - Qual o resultado?: integer (nullable = true)
#  |-- B0101 - Algum médico já lhe deu o diagnóstico de diabetes?: integer (nullable = true)
#  |-- B0102 - Algum médico já lhe deu o diagnóstico de hipertensão?: integer (nullable = true)
#  |-- B0103 - Algum médico já lhe deu o diagnóstico de asma/bronquite/enfisema/doenças respiratória crônica ou doença de pulmão?: integer (nullable = true)
#  |-- B0104 - Algum médico já lhe deu o diagnóstico de doenças do coração (infarto, angina, insuficiência cardíaca, arritmia)?: integer (nullable = true)
#  |-- B0105 - Algum médico já lhe deu o diagnóstico de depressão?: integer (nullable = true)
#  |-- B0106 - Algum médico já lhe deu o diagnóstico de câncer?: integer (nullable = true)
#  |-- B011 - Qual foi o resultado do teste?  Na semana passada, devido à pandemia do Coronavírus, em que medida o(a) Sr(a) restringiu o contato com as pessoas? : integer (nullable = true)
#  |-- C001 - Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?: integer (nullable = true)
#  |-- C002 - Na semana passada, estava temporariamente afastado de algum trabalho?: integer (nullable = true)
#  |-- C003 - Qual o principal motivo deste afastamento temporário?: integer (nullable = true)
#  |-- C004 - Continuou a ser remunerado (mesmo que parcialmente) por esse trabalho: integer (nullable = true)
#  |-- C005 - Há quanto tempo está afastado desse trabalho?: integer (nullable = true)
#  |-- C0051 -  tempo que estava afastado (De 1 mês a menos de 1 ano) : integer (nullable = true)
#  |-- C0052 - tempo que estava afastado (De 1 ano a menos de 2 anos) : integer (nullable = true)
#  |-- C0053 - tempo que estava afastado (de 02 anos a 98 anos) : integer (nullable = true)
#  |-- C006 - Tem mais de um trabalho: integer (nullable = true)
#  |-- C007 - No trabalho (único ou principal) que tinha nessa semana, era:: integer (nullable = true)
#  |-- C007A - Esse trabalho era na área:: integer (nullable = true)
#  |-- C007B - Tem carteira de trabalho assinada ou é funcionário público estatutário?: integer (nullable = true)
#  |-- C007C - Que tipo de trabalho, cargo ou função você realiza no seu trabalho (único ou principal)? : integer (nullable = true)
#  |-- C007D - Qual é a principal atividade do local ou empresa em que você trabalha? : integer (nullable = true)
#  |-- C007E - Na semana passada, quantos empregados trabalhavam nesse negócio/empresa que ... tinha ?: integer (nullable = true)
#  |-- C007E1 - 1 a 5 empregados: integer (nullable = true)
#  |-- C007E2 - 6 a 10 empregados: integer (nullable = true)
#  |-- C007F - No trabalho (único ou principal) que tinha nessa semana, o(a) Sr(a) estava com o contrato de trabalho suspenso?: integer (nullable = true)
#  |-- C008 - Quantas horas, por semana, normalmente trabalhava?: integer (nullable = true)
#  |-- C009 - Quantas horas, na semana passada, de fato trabalhou?: integer (nullable = true)
#  |-- C009A - Na semana passada, o(a) Sr(a) gostaria de ter trabalhado mais horas do que as de fato trabalhadas? : integer (nullable = true)
#  |-- C010 - Quanto recebia (ou retirava) normalmente em todos os seus trabalhos: integer (nullable = true)
#  |-- C0101 - Recebia/retirava normalmente em dinheiro: integer (nullable = true)
#  |-- C01011 - Número da faixa do rendimento/retirada em dinheiro: integer (nullable = true)
#  |-- C01012 - Valor em dinheiro: integer (nullable = true)
#  |-- C0102 - Recebia normalmente em produtos e mercadorias: integer (nullable = true)
#  |-- C01021 - Número da faixa do rendimento/retirada em produtos e mercadorias: integer (nullable = true)
#  |-- C01022 - Valor em produtos e mercadorias: integer (nullable = true)
#  |-- C0103 - Recebia normalmente somente em benefícios: integer (nullable = true)
#  |-- C0104 - Era não remunerado: integer (nullable = true)
#  |-- C011A - Quanto recebia (ou retirava) efetivamente em todos os seus trabalhos: integer (nullable = true)
#  |-- C011A1 - Recebia/retirava efetivamente em dinheiro: integer (nullable = true)
#  |-- C011A11 - Número da faixa do rendimento/retirada em dinheiro: integer (nullable = true)
#  |-- C011A12 - Valor em dinheiro: integer (nullable = true)
#  |-- C011A2 - Recebia efetivamente em produtos e mercadorias: integer (nullable = true)
#  |-- C011A21 - Número da faixa do rendimento/retirada em produtos e mercadorias: integer (nullable = true)
#  |-- C011A22 - Valor em produtos e mercadorias: integer (nullable = true)
#  |-- C012 - Na maior parte do tempo, na semana passada, esse trabalho (único ou principal) foi exercido no mesmo local em que costuma trabalhar? : integer (nullable = true)
#  |-- C013 - Na semana passada, o(a) Sr(a) estava em trabalho remoto (home office ou teletrabalho)?: integer (nullable = true)
#  |-- C014 - O(A) Sr(a) contribui para o INSS?  : integer (nullable = true)
#  |-- C015 - Na semana passada ___ tomou alguma providência efetiva para conseguir trabalho?  : integer (nullable = true)
#  |-- C016 - Qual o principal motivo de não ter procurado trabalho na semana passada? : integer (nullable = true)
#  |-- C017A - Embora você não tenha procurado trabalho, gostaria de ter trabalhado na semana passada?: integer (nullable = true)
#  |-- D0011 - Rendimento recebido de aposentadoria e pensão por todos os moradores: integer (nullable = true)
#  |-- D0013 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0021 - Rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio: integer (nullable = true)
#  |-- D0023 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0031 - Rendimentos de Programa Bolsa Família: integer (nullable = true)
#  |-- D0033 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0041 -  No mês de ... (mês de referência), ... recebeu rendimentos de Benefício Assistencial de Prestação Continuada  BPC-LOAS?: integer (nullable = true)
#  |-- D0043 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0051 - Auxílios emergenciais relacionados ao coronavirus: integer (nullable = true)
#  |-- D0053 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0061 - Seguro desemprego: integer (nullable = true)
#  |-- D0063 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- D0071 - Outros rendimentos, como aluguel, arrendamento, previdência privada, bolsa de estudos, rendimentos de aplicação financeira etc.: integer (nullable = true)
#  |-- D0073 - Somatório dos valores recebidos: integer (nullable = true)
#  |-- E001 - Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  : integer (nullable = true)
#  |-- E0021 - Este empréstimo foi adquirido com banco ou financeira: integer (nullable = true)
#  |-- E0022 - Este empréstimo foi adquirido com parente ou amigo: integer (nullable = true)
#  |-- E0023 - Este empréstimo foi adquirido com empregados ou patrão: integer (nullable = true)
#  |-- E0024 - Este empréstimo foi adquirido com outro local ou pessoa: integer (nullable = true)
#  |-- F001 - Este domicílio é: : integer (nullable = true)
#  |-- F0021 - Qual foi o valor mensal do aluguel pago, ou que deveria ter sido pago, no mês de referência?: integer (nullable = true)
#  |-- F0022 - Número da faixa do aluguel pago: integer (nullable = true)
#  |-- F002A1 - No seu domicílio há os seguintes itens básicos de limpeza e proteção: sabão ou detergente: integer (nullable = true)
#  |-- F002A2 - No seu domicílio há os seguintes itens básicos de limpeza e proteção: álcool 70% ou superior (gel ou líquido): integer (nullable = true)
#  |-- F002A3 - No seu domicílio há os seguintes itens básicos de limpeza e proteção: máscaras: integer (nullable = true)
#  |-- F002A4 - No seu domicílio há os seguintes itens básicos de limpeza e proteção: luvas descartáveis: integer (nullable = true)
#  |-- F002A5 - No seu domicílio há os seguintes itens básicos de limpeza e proteção: água sanitária ou desinfetante: integer (nullable = true)
#  |-- F0061 - Quem respondeu ao questionário?: integer (nullable = true)
#  |-- F006 - Número de ordem do morador que prestou as informações: integer (nullable = true)
#  |-- periodo: string (nullable = false)

# %% [markdown]
# ## Criando chave única (CODIGO COLUNA + TIPO_VALOR) no dicionario

# %%
from pyspark.sql.functions import broadcast, when, col, concat, lit
from functools import reduce

# 1. Preparar o dicionário com chave única: codigo + tipo_valor
df_dict_prep = df_dict.withColumn("chave_unica",
    concat(col("codigo"), lit("_"), col("tipo_valor")))

# 2. Coletar os mapeamentos
mapeamentos = df_dict_prep.select("codigo", "chave_unica", "tipo_valor", "descricao_valor").collect()

mapeamentos_dict = {row['chave_unica']: row['descricao_valor'] for row in mapeamentos}

mapeamentos_dict
# Out:
# {'UF_11': 'Rondônia', 'UF_12': 'Acre', 'UF_13': 'Amazonas', 'UF_14': 'Roraima', 'UF_15': 'Pará', 'UF_16': 'Amapá', 'UF_17': 'Tocantins', 'UF_21': 'Maranhão', 'UF_22': 'Piauí', 'UF_23': 'Ceará', 'UF_24': 'Rio Grande do Norte', 'UF_25': 'Paraíba', 'UF_26': 'Pernambuco', 'UF_27': 'Alagoas', 'UF_28': 'Sergipe', 'UF_29': 'Bahia', 'UF_31': 'Minas Gerais', 'UF_32': 'Espírito Santo', 'UF_33': 'Rio de Janeiro', 'UF_35': 'São Paulo', 'UF_41': 'Paraná', 'UF_42': 'Santa Catarina', 'UF_43': 'Rio Grande do Sul', 'UF_50': 'Mato Grosso do Sul', 'UF_51': 'Mato Grosso', 'UF_52': 'Goiás', 'UF_53': 'Distrito Federal', 'CAPITAL_11': 'Município de Porto Velho (RO)', 'CAPITAL_12': 'Município de Rio Branco (AC)', 'CAPITAL_13': 'Município de Manaus (AM)', 'CAPITAL_14': 'Município de Boa Vista (RR)', 'CAPITAL_15': 'Município de Belém (PA)', 'CAPITAL_16': 'Município de Macapá (AP)', 'CAPITAL_17': 'Município de Palmas (TO)', 'CAPITAL_21': 'Município de São Luís (MA)', 'CAPITAL_22': 'Município de Teresina (PI)', 'CAPITAL_23': 'Município de Fortaleza (CE)', 'CAPITAL_24': 'Município de Natal (RN)', 'CAPITAL_25': 'Município de João Pessoa (PB)', 'CAPITAL_26': 'Município de Recife (PE)', 'CAPITAL_27': 'Município de Maceió (AL)', 'CAPITAL_28': 'Município de Aracaju (SE)', 'CAPITAL_29': 'Município de Salvador (BA)', 'CAPITAL_31': 'Município de Belo Horizonte (MG)', 'CAPITAL_32': 'Município de Vitória (ES)', 'CAPITAL_33': 'Município de Rio de Janeiro (RJ)', 'CAPITAL_35': 'Município de São Paulo (SP)', 'CAPITAL_41': 'Município de Curitiba (PR)', 'CAPITAL_42': 'Município de Florianópolis (SC)', 'CAPITAL_43': 'Município de Porto Alegre (RS)', 'CAPITAL_50': 'Município de Campo Grande (MS)', 'CAPITAL_51': 'Município de Cuiabá (MT)', 'CAPITAL_52': 'Município de Goiânia (GO)', 'CAPITAL_53': 'Município de Brasília (DF)', 'RM_RIDE_13': 'Região Metropolitana de Manaus (AM)', 'RM_RIDE_15': 'Região Metropolitana de Belém (PA)', 'RM_RIDE_16': 'Região Metropolitana de Macapá (AP)', 'RM_RIDE_21': 'Região Metropolitana de Grande São', None: 'Não aplicado', 'RM_RIDE_22': 'Região Administrativa Integrada', 'RM_RIDE_23': 'Região Metropolitana de Fortaleza (CE)', 'RM_RIDE_24': 'Região Metropolitana de Natal (RN)', 'RM_RIDE_25': 'Região Metropolitana de João Pessoa (PB)', 'RM_RIDE_26': 'Região Metropolitana de Recife (PE)', 'RM_RIDE_27': 'Região Metropolitana de Maceió (AL)', 'RM_RIDE_28': 'Região Metropolitana de Aracaju (SE)', 'RM_RIDE_29': 'Região Metropolitana de Salvador (BA)', 'RM_RIDE_31': 'Região Metropolitana de Belo Horizonte (MG)', 'RM_RIDE_32': 'Região Metropolitana de Grande Vitória (ES)', 'RM_RIDE_33': 'Região Metropolitana de Rio de Janeiro (RJ)', 'RM_RIDE_35': 'Região Metropolitana de São Paulo (SP)', 'RM_RIDE_41': 'Região Metropolitana de Curitiba (PR)', 'RM_RIDE_42': 'Região Metropolitana de Florianópolis (SC)', 'RM_RIDE_43': 'Região Metropolitana de Porto Alegre (RS)', 'RM_RIDE_51': 'Região Metropolitana de Vale do Rio Cuiabá (MT)', 'RM_RIDE_52': 'Região Metropolitana de Goiânia (GO)', 'V1008_01 a 14': 'Número do domicílio', 'V1012_1 a 4': None, 'V1013_01 a 12': 'Mês da pesquisa (janeiro a dezembro)', 'V1016_1 a 99': 'Número da entrevista', 'Estrato_Estrato': None, 'UPA_UPA - Unidade primária de amostragem': None, 'V1022_1': 'Urbana', 'V1022_2': 'Rural', 'V1023_1': 'Capital', 'V1023_2': 'Resto da RM (Região Metropolitana, excluindo a capital)', 'V1023_3': 'Resto da RIDE (Região Integrada de Desenvolvimento Econômico, excluindo a capital) ', 'V1023_4': 'Resto da UF  (Unidade da Federação, excluindo a região metropolitana e a RIDE)', 'V1031_6 dígitos e 8 casas decimais': 'Peso mensal com correção de não entrevista sem pós estratificação pela projeção de população', 'V1032_6 dígitos e 8 casas decimais': 'Peso mensal com correção de não entrevista com pós estratificação pela projeção de população', 'A001_01 a 30': None, 'A001A_01': 'Pessoa responsável pelo domicílio ', 'A001A_02': 'Cônjuge ou companheiro(a) de sexo diferente', 'A001A_03': 'Cônjuge ou companheiro(a) do ...

# %% [markdown]
# # SELEÇÃO APENAS DAS PERGUNTAS QUE USAREMOS, TRADUZINDO OS VALORES DAS COLUNAS E EXPORTANDO CSV (GOLD)

# %%
# lista de colunas que você quer manter
colunas = [
    # Características Clínicas dos Sintomas
    "B0011 - Na semana passada teve febre?",
    "B0012 - Na semana passada teve tosse?",
    "B0014 - Na semana passada teve dificuldade para respirar?",
    "B00111 - Na semana passada teve perda de cheiro ou sabor?",
    "B002 - Por causa disso, foi a algum estabelecimento de saúde?",
    "B008 - O(A) Sr(a) fez algum teste para saber se estava infectado(a) pelo coronavírus? ",

    "B009A - Fez o exame coletado com cotonete na boca e/ou nariz (SWAB)? ",
    "B009B - Qual o resultado?",
    "B009C - Fez o exame de coleta de sangue através de furo no dedo?",
    "B009D - Qual o resultado?",
    "B009E - Fez o exame de coleta de sangue através da veia da braço?",
    "B009F - Qual o resultado?",
    # Características da População
    "UF - Unidade da Federação",
    "A002 - Idade do morador ",
    "A003 - Sexo",
    "A004 - Cor ou raça",
    "A005 - Escolaridade",
    "B0102 - Algum médico já lhe deu o diagnóstico de hipertensão?",
    "B011 - Qual foi o resultado do teste?  Na semana passada, devido à pandemia do Coronavírus, em que medida o(a) Sr(a) restringiu o contato com as pessoas? ",

    # Características Econômicas
    "C001 - Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?",
    "C013 - Na semana passada, o(a) Sr(a) estava em trabalho remoto (home office ou teletrabalho)?",
    "C01012 - Valor em dinheiro",
    "D0051 - Auxílios emergenciais relacionados ao coronavirus",
    "D0053 - Somatório dos valores recebidos",
    "E001 - Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  ",
    "periodo"
]

# filtrar apenas essas colunas
df_filtrado = df_total_renomeado[colunas]

# %%
#Transformar os valores tudo em string

from pyspark.sql import functions as F
from pyspark.sql.types import StringType

# Converte TODAS as colunas do DataFrame para string
df_filtrado = df_filtrado.select(
    [F.col(c).cast(StringType()).alias(c) for c in df_filtrado.columns]
)

df_resultado = df_filtrado

# %%
from pyspark.sql import functions as F

colunas_excecao = [
    "C01012 - Valor em dinheiro",
    "D0053 - Somatório dos valores recebidos"
]

# Criar dicionário (se ainda não existir)
if 'mapeamentos_dict' not in locals():
    mapeamentos = df_dict_prep.select("codigo", "chave_unica", "descricao_valor").collect()
    mapeamentos_dict = {
        row['chave_unica']: row['descricao_valor']
        for row in mapeamentos if row['chave_unica'] is not None
    }

df_com_descricoes = df_resultado

for col in df_com_descricoes.columns:
    if col in colunas_excecao:
        print(f"Pulando coluna {col}")
        continue

    codigo = col.split(" - ")[0] if " - " in col else col

    # Pegar só os mapeamentos daquele código
    chaves = {
        k: v
        for k, v in mapeamentos_dict.items()
        if isinstance(k, str) and k.startswith(codigo + "_")
    }

    if not chaves:
        continue

    # Normalizar: transformar valor cru "1" em "B0011_1"
    col_norm = F.when(F.col(col).isNotNull(), F.concat(F.lit(codigo + "_"), F.col(col))).otherwise(None)

    # Substituir pelo dicionário
    case_expr = col_norm
    for chave, desc in chaves.items():
        case_expr = F.when(col_norm == chave, desc).otherwise(case_expr)

    df_com_descricoes = df_com_descricoes.withColumn(col, case_expr)

print("Substituições aplicadas (com prefixo código_valor)")
# Out:
# Pulando coluna C01012 - Valor em dinheiro
# Pulando coluna D0053 - Somatório dos valores recebidos
# Substituições aplicadas (com prefixo código_valor)

# %%
df_com_descricoes.select("B0011 - Na semana passada teve febre?") \
    .distinct() \
    .show(truncate=False)
# Out:
# +-------------------------------------+
# |B0011 - Na semana passada teve febre?|
# +-------------------------------------+
# |Não                                  |
# |Não sabe                             |
# |Sim                                  |
# |Ignorado                             |
# +-------------------------------------+

# %%
#Retirando o codigo da pergunta nos valores dessa coluna

coluna = "A002 - Idade do morador "

df_com_descricoes = df_com_descricoes.withColumn(
    coluna,
    F.when(F.col(coluna).contains("_"), F.split(F.col(coluna), "_").getItem(1))
     .otherwise(F.col(coluna))
)

# %%
# Exportar relatório
df_com_descricoes.coalesce(1) \
    .write \
    .mode("overwrite") \
    .option("header", "true") \
    .option("sep", ",") \
    .option("encoding", "UTF-8") \
    .option("quote", '"') \
    .option("escape", '"') \
    .csv('s3://898876087650/data_output/CSV/')

print("Relatório de processamento exportado!")
# Out:
# ✅ Relatório de processamento exportado!
