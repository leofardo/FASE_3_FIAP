# %%
import pandas as pd

df = pd.read_excel("Dicionario_PNAD_COVID_092020_20220621 - Copia.xls")

df["Código da variável"] = df["Código da variável"].ffill()
df["Descrição"] = df["Descrição"].ffill()

df.to_csv("Dicionario_PNAD_COVID_092020_tratado.csv", index=False)

# %%
import pandas as pd

df = pd.read_excel("Dicionario_PNAD_COVID_102020_20220621 - Copia.xls")

df["Código da variável"] = df["Código da variável"].ffill()
df["Descrição"] = df["Descrição"].ffill()

df.to_excel("Dicionario_PNAD_COVID_102020_tratado.xlsx", index=False)

# %%
import pandas as pd

df = pd.read_excel("Dicionario_PNAD_COVID_112020_20220621 - Copia.xls")

df["Código da variável"] = df["Código da variável"].ffill()
df["Descrição"] = df["Descrição"].ffill()

df.to_excel("Dicionario_PNAD_COVID_112020_tratado.xlsx", index=False)
